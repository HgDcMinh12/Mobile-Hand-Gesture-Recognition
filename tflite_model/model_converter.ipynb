# %%
# %cd '/content/drive/MyDrive/Colab Notebooks/Nhận dạng/Mobile Hand Gesture Recognition/tflite model'
# Out:
# /content/drive/MyDrive/Colab Notebooks/Nhận dạng/Mobile Hand Gesture Recognition/tflite model

# %%
# !ls
# Out:
# hand_gesture_Adam.h5   hand_gesture_SGD.h5  model_SGD.tflite
# hand_gesture_NAdam.h5  model_NAdam.tflite   Untitled0.ipynb

# %%
import tensorflow as tf

model = tf.keras.models.load_model('hand_gesture_Adam.h5')
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()
open('model_Adam.tflite','wb').write(tflite_model)
# Out:
# WARNING:absl:Function `_wrapped_model` contains input name(s) mobilenetv2_1.00_224_input with unsupported characters which will be renamed to mobilenetv2_1_00_224_input in the SavedModel.
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# INFO:tensorflow:Assets written to: /tmp/tmpjwe0yl1e/assets
# INFO:tensorflow:Assets written to: /tmp/tmpjwe0yl1e/assets
# 14891232
